# %%
import numpy

# %%
import import_ipynb

# %%
from test1 import print_name
# Out:
# importing Jupyter notebook from test1.ipynb

# %%
import lantern

# %%
lantern.people()
# Out:
#     age first_name  gender        id        last_name  \
# 0    57      Rosio  Female  93-90/37         Espinoza
# 1    44         文婍    Male  40-39/36                祁
# 2    54     Iivari    Male  64-63/69         Pennanen
# 3    17         혜연  Female  07-98/21                빙
# 4    60         예섬   Other  11-28/54                빙
# 5    49     Arnaud    Male  12-79/91          Tomaino
# 6    48      Δανάη  Female  79-10/89         Βικελίδη
# 7    33       Rena  Female  41-12/00            Hrabě
# 8    33         アン  Female  29-54/58                呉
# 9    22          睿    Male  22-54/30                郎
# 10   48       Hüma  Female  39-24/15          Erdoğan
# 11   55       Alpo    Male  56-51/42           Uotila
# 12   21  Kazimierz    Male  44-45/44        Świnarski
# 13   38     Lőrinc    Male  94-29/39         Moldován
# 14   23      Cecil    Male  34-14/07          Beranek
# 15   43    Людмила  Female  18-37/24        Филиппова
# ...

# %%
import qgrid
df = lantern.people()

# %%
qgrid_widget = qgrid.show_grid(df)

# %%
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
